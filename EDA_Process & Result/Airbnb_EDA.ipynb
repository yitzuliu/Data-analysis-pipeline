# %% [markdown]
# # Airbnb Dataset: Exploratory Data Analysis (EDA)
#
# This notebook presents a comprehensive, step-by-step EDA of the cleaned Airbnb NYC
# dataset (17,230 reviewed listings) to uncover patterns in pricing, property characteristics,
# location, and review scores.
#
# The notebook uses the `AirbnbEDAAnalyzer` class from `EDA.py` as the analytical engine.
# Separating execution cells from the backend class allows each analysis step to be
# narrated independently while relying on production-grade, tested backend code.
#
# > **Analytical caveat (survivor bias):** The dataset contains only listings that have
# > received at least one guest review. New, unreviewed listings were excluded during ETL
# > (see `ETL_Airbnb_Process.ipynb` — Step 3.4). All conclusions about ratings and market
# > behavior apply specifically to the **established, reviewed-listing population**.
#
# ## Analytical Questions
# 1. **Univariate:** What is the shape and distribution of critical features like Price and Review Scores?
# 2. **Categorical:** Which neighbourhoods and room types dominate the platform?
# 3. **Bivariate (Price):** How does location couple with listing price?
# 4. **Bivariate (Rating):** Which areas deliver high guest satisfaction at below-market prices?
# 5. **Business Insight:** Where are the explicit market premiums and value-disparity opportunities?

# %% [markdown]
# ## 1. Environment Setup & Data Loading

# %%
import pandas as pd
import numpy as np
import sys
import os
import warnings

warnings.filterwarnings('ignore')

# Add the EDA_Process directory to path so we can import EDA.py
eda_dir = os.path.dirname(os.path.abspath('EDA.py'))
if eda_dir not in sys.path:
    sys.path.insert(0, eda_dir)

from EDA import AirbnbEDAAnalyzer

# Resolve the path to the cleaned CSV produced by the ETL pipeline
data_path = '../Datasource/airbnb_clean.csv' if os.path.exists('../Datasource/') else 'Datasource/airbnb_clean.csv'

analyzer = AirbnbEDAAnalyzer(data_path=data_path)
df = analyzer.load_data()

print(f'Loaded: {len(df):,} rows x {len(df.columns)} columns')
display(df.head(3))

# %% [markdown]
# ## 2. Univariate Analysis — Variable Shapes & Distributions
#
# We compute descriptive statistics for all analytical numerical variables.
#
# > **Note on `Number of Records`:** This column is intentionally excluded.
# > After ETL cleaning, every listing has exactly 1 record (std = 0, constant).
# > A constant column carries no information and produces NaN in correlation matrices.

# %%
univariate_metrics = analyzer.perform_univariate_analysis()
stats_df = pd.DataFrame(univariate_metrics).T.round(3)
display(stats_df)

# %% [markdown]
# > **Insight — Price (Extreme Right Skew):**
# > Price skewness ≈ **23.8** and kurtosis ≈ **1,303** — an extreme right-skewed distribution.
# > The true typical listing price is the **median ($137)**, not the mean ($160).
# > Only 0.15% of listings (25 properties) are priced above $1,000, yet they drag the mean
# > $23 above the median. Visualizations use a 95th-percentile cap ($340) to display the
# > distribution where 95% of listings actually sit.
# >
# > **Insight — Review Scores Rating (Survivor Bias):**
# > Mean rating 92.6/100, median 94.0, low spread (std ≈ 8.6). The narrow, high-end
# > distribution is consistent with a **survivor-bias / hygiene-factor effect**: listings that
# > cannot maintain ~90+ ratings likely lose competitiveness and exit the platform.
# > High ratings are a baseline requirement, not a differentiator.
# >
# > **Insight — Number of Reviews (Winner-Takes-Most):**
# > Median = 6 reviews vs. max = 256. Exactly half of all listings have ≤6 reviews,
# > while a small fraction of veteran hosts accumulate the majority of guest interactions.

# %% [markdown]
# ## 3. Categorical Analysis — Market Segment Shares

# %%
categorical_metrics = analyzer.analyze_categorical_variables()

print('--- Market Share by Neighbourhood ---')
nb_pct = pd.Series(categorical_metrics['Neighbourhood']['category_percentages']).round(1)
display(nb_pct.to_frame(name='% share'))

print('\n--- Market Share by Room Type ---')
rt_pct = pd.Series(categorical_metrics['Room Type']['category_percentages']).round(1)
display(rt_pct.to_frame(name='% share'))

# %% [markdown]
# > **Insight — Market Concentration:**
# > Manhattan (54.6%) + Brooklyn (37.9%) together control **92.5% of the market**.
# > The three outer boroughs combined represent only 7.5% of listings.
# > This duopoly structure sets the context for all geographic price-premium analysis.
# >
# > **Insight — Room Type:**
# > 62.5% of listings are 'Entire home/apt', confirming that Airbnb NYC operates
# > primarily as a **vacation rental platform** rather than a peer-to-peer room-sharing service.

# %% [markdown]
# ## 4. Bivariate Analysis — Price & Rating by Location
#
# Two dimensions are analyzed simultaneously:
# - **Price × Location** — geographic pricing premium/discount matrix
# - **Rating × Location** — the analytic foundation for the 'value-disparity' thesis

# %%
bivariate = analyzer.perform_bivariate_analysis()

# Price × Neighbourhood
overall_avg = df['Price'].mean()
nb_price_mean = pd.Series(bivariate['neighborhood_price']['mean'])
nb_price_median = pd.Series(bivariate['neighborhood_price']['median'])
nb_price_premium = ((nb_price_mean - overall_avg) / overall_avg * 100).round(1)

price_table = pd.DataFrame({
    'Avg Price ($)':    nb_price_mean.round(0).astype(int),
    'Median Price ($)': nb_price_median.round(0).astype(int),
    'vs Market (%)':    nb_price_premium
}).sort_values('Avg Price ($)', ascending=False)

print(f'=== Price by Neighbourhood (Market avg: ${overall_avg:.0f}) ===')
display(price_table)

# Rating × Neighbourhood
nb_rating_mean = pd.Series(bivariate['neighbourhood_rating']['mean'])
nb_rating_median = pd.Series(bivariate['neighbourhood_rating']['median'])

rating_table = pd.DataFrame({
    'Avg Rating (/100)':    nb_rating_mean,
    'Median Rating (/100)': nb_rating_median
}).sort_values('Avg Rating (/100)', ascending=False)

print(f'\n=== Review Score Rating by Neighbourhood (Market avg: {df["Review Scores Rating"].mean():.1f}) ===')
display(rating_table)

# %% [markdown]
# > **Insight — Geographic Value Disparity:**
# > Brooklyn has the **highest average rating (≥93.0)** of all boroughs while
# > simultaneously sitting ~17% **below the market average price** ($130 vs. $160).
# > This creates a quantifiable 'high value-to-price' market segment:
# > guests can access premium-rated accommodation at a meaningful discount.
# >
# > **Insight — Price is Driven by Location, Not Ratings:**
# > Manhattan commands a ~17% price premium over the market average despite having
# > a comparable (not superior) average rating. Location is the primary pricing determinant;
# > ratings function as a market-survival threshold rather than a premium-pricing lever.

# %% [markdown]
# ## 5. Business Insights — Market Premiums & Value Opportunities

# %%
business_insights = analyzer.generate_business_insights()

# Room type economics
print('=== Room Type Price Premiums (vs Private Room baseline) ===')
rt_premiums = pd.Series(business_insights['room_type_economics']['room_type_premiums'])
display(rt_premiums.to_frame(name='Premium (%)').sort_values('Premium (%)', ascending=False))

# Value-disparity matrix
print('\n=== Value-Disparity Matrix (High Rating + Below-Market Price) ===')
vd = business_insights.get('value_disparity_matrix', {})
if vd:
    vd_df = pd.DataFrame({
        'Avg Price ($)':  pd.Series(vd['avg_price']).round(0).astype(int),
        'Avg Rating':     pd.Series(vd['avg_rating']),
        'Listings':       pd.Series(vd['listing_count']).astype(int),
        'Price Discount (%)': pd.Series(vd['price_discount_pct'])
    })
    display(vd_df)

# Price-Rating correlation
corr = business_insights.get('price_rating_correlation', 'N/A')
print(f'\nPrice vs. Rating correlation coefficient: r = {corr}')
print('(Near-zero r confirms: higher ratings do NOT command higher prices.)')

# %% [markdown]
# ## 6. Visualizations

# %%
# create_visualizations() is the correct method name in EDA.py
# save_plots=True saves charts to the 'plots/' directory at 300 DPI
analyzer.create_visualizations(save_plots=True)
print('All visualizations saved to plots/ directory.')
