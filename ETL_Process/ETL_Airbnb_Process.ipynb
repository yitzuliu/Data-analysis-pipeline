# %% [markdown]
# # Airbnb Dataset: ETL Processing Pipeline
#
# This notebook demonstrates the Extract, Transform, and Load (ETL) pipeline for the Airbnb NYC dataset.
# It executes each transformation step individually via the `AirbnbETLProcessor` class from `ETL.py`,
# displaying how the data evolves at each stage so that the full data lineage is transparent and auditable.
#
# ## Objectives
# 1. **Extract** — Load the raw Excel source data
# 2. **Standardize** — Clean column names and remove duplicate host records
# 3. **Type-cast** — Parse dates and enforce numeric types
# 4. **Document missing data** — Explicitly log and explain all gaps before dropping
# 5. **Validate** — Apply business rules to remove logically invalid records
# 6. **Optimize** — Downcast types and fix Zipcode dtype for memory efficiency
# 7. **Load** — Save the final clean dataset for downstream EDA

# %% [markdown]
# ## 1. Setup and Import Pipeline Engine

# %%
import pandas as pd
import sys
import os
import warnings

warnings.filterwarnings('ignore')

# Add the ETL_Process directory to the Python path so we can import ETL.py
etl_dir = os.path.dirname(os.path.abspath('ETL.py'))
if etl_dir not in sys.path:
    sys.path.insert(0, etl_dir)

from ETL import AirbnbETLProcessor

# Resolve paths relative to both the project root and the ETL_Process folder
input_path  = '../Datasource/airbnb.xlsx'     if os.path.exists('../Datasource/') else 'Datasource/airbnb.xlsx'
output_path = '../Datasource/airbnb_clean.csv' if os.path.exists('../Datasource/') else 'Datasource/airbnb_clean.csv'

processor = AirbnbETLProcessor(input_path=input_path, output_path=output_path)
print('ETL Engine initialized successfully.')

# %% [markdown]
# ## 2. Extraction — Load Raw Data
#
# We load the initial raw dataset to observe its unprocessed state before any transformation.

# %%
df_raw = processor.load_data()
print(f'Initial Dataset Shape: {df_raw.shape}')
print(f'\nColumn names (raw):')
for i, col in enumerate(df_raw.columns, 1):
    print(f'  {i:2d}. "{col}"')  # Quotes reveal trailing whitespace in 'Neighbourhood '
display(df_raw.head(3))

# %% [markdown]
# ## 3. Transformation
#
# We process the dataset sequentially through discrete, testable steps.
# Each step prints its row-count delta so the data lineage is fully traceable.

# %% [markdown]
# ### Step 3.1 — Clean Column Names & Remove Duplicates
#
# **Column names:** The raw source has a trailing space in `'Neighbourhood '`.
# If left unaddressed, every `.groupby('Neighbourhood')` call would silently fail.
#
# **Deduplication key:** We use `(Host Id, Host Since)` rather than `Host Id` alone.
# A host legitimately owns multiple listings, so Host Id alone is not sufficient.
# The `Host Since` date identifies the host *account*, and duplicate
# `(Host Id, Host Since)` pairs represent data entry redundancies in the source system.

# %%
df_clean = processor.clean_column_names(df_raw)
print(f'Before deduplication: {len(df_clean):,} rows')
df_clean = processor.remove_duplicates(df_clean)
print(f'After  deduplication: {len(df_clean):,} rows')

# %% [markdown]
# ### Step 3.2 — Parse Data Types & Drop Unnecessary Columns
#
# - `Host Since` → parsed from raw `DD/MM/YYYY` string to a `date` object.
# - `Price`, `Number of Records`, `Number Of Reviews`, `Review Scores Rating` → forced to numeric (`errors='coerce'` so unparseable strings become NaN rather than crashing).
# - `Review Scores Rating (bin)` and `Name` are dropped: the bin column is a pre-computed derived column (redundant with the continuous rating), and the listing name adds no analytical value.

# %%
df_clean = processor.convert_data_types(df_clean)
df_clean = processor.drop_unnecessary_columns(df_clean)
print('Column data types after casting:')
display(df_clean.dtypes.to_frame(name='dtype'))

# %% [markdown]
# ### Step 3.3 — Hierarchical Price Imputation (Defensive Design)
#
# > **Key observation:** In the current dataset, `Price` has **zero missing values**.
# > The `impute_missing_prices()` step is therefore a **no-op** for this run.
#
# It is retained as a **defensive component** for future data refreshes or
# similar datasets (e.g., scraped data or nightly API pulls) where prices
# may be temporarily absent. The strategy, if triggered, works as follows:
#
# 1. **Zipcode Median** — most granular geographic anchor (same micro-market)
# 2. **Neighbourhood Median** — broader fallback if the Zipcode has no price data
# 3. **Drop** — row is discarded only if both geographic anchors fail
#
# This approach preserves the maximum number of records while using
# the most locally relevant pricing reference at each fallback level.

# %%
pre_missing = df_clean['Price'].isna().sum()
df_clean = processor.impute_missing_prices(df_clean)
post_missing = df_clean['Price'].isna().sum()
print(f'Price missing values: {pre_missing} → {post_missing}')
print('(No imputation required for this dataset version.)')

# %% [markdown]
# ### Step 3.4 — Missing Data Pattern Analysis
#
# Before performing the final drop, we generate a structured report of every
# remaining gap. This makes the data loss **fully transparent and auditable**.
#
# **Primary source of data loss — `Review Scores Rating`:**
#
# | Column | Missing (n) | % of post-dedup rows | Business Reason |
# |---|---|---|---|
# | `Review Scores Rating` | ~8,323 | ~34% | New listings with no guest reviews yet have no rating |
# | `Beds` | ~85 | ~0.3% | Data entry omissions in the source system |
# | `Zipcode` | ~134 | ~0.5% | Incomplete host registration data |
#
# > **⚠️ Analytical Caveat (Survivor Bias):**
# > Dropping rows where `Review Scores Rating` is null means this analysis
# > reflects **only established listings that have been reviewed at least once**.
# > Newly listed properties are excluded. All conclusions about ratings
# > (e.g., the 'hygiene factor' thesis) apply to this reviewed-listings subset.

# %%
# Log the missing data pattern BEFORE the final drop
processor.analyze_missing_patterns(df_clean)

# Show a DataFrame summary for visual inspection
missing_report = df_clean.isnull().sum().to_frame(name='missing_count')
missing_report['missing_pct'] = (missing_report['missing_count'] / len(df_clean) * 100).round(2)
display(missing_report[missing_report['missing_count'] > 0])

# %% [markdown]
# ### Step 3.5 — Data Validation & Memory Optimization
#
# **Business rules applied (validation):**
# - `Review Scores Rating` ∈ [1, 100] — ratings outside this range are invalid
# - `Number of Records` ≥ 1 — zero-record listings are data anomalies
# - `Beds` ≥ 1 — properties with 0 beds are not valid rental units
# - All key fields must be non-null (final dropna)
#
# **Memory optimization:**
# - `Neighbourhood`, `Room Type`, `Property Type` → `category` dtype
# - `Zipcode` → string (geographic identifier; arithmetic operations are meaningless)

# %%
pre_validation = len(df_clean)
df_clean = processor.validate_data_quality(df_clean)
print(f'Rows before validation: {pre_validation:,}')
print(f'Rows after  validation: {len(df_clean):,}')
print(f'Rows removed:           {pre_validation - len(df_clean):,}')
print()

df_clean = processor.optimize_data_types(df_clean)
mem_mb = df_clean.memory_usage(deep=True).sum() / 1024**2
print(f'Memory footprint after optimization: {mem_mb:.2f} MB')
print(f'Column dtypes after optimization:')
display(df_clean.dtypes.to_frame(name='dtype'))

# %% [markdown]
# ## 4. Load — Save Final Dataset
#
# We inspect the final cleaned table, run a sanity summary, and persist it to `.csv`
# for downstream EDA consumption.

# %%
print('=== Final Cleaned Dataset (head) ===')
display(df_clean.head(5))

print('\n=== Data Summary ===')
# generate_data_summary is the correct method name in ETL.py
summary = processor.generate_data_summary(df_clean)
print(f"Total rows:       {summary['total_rows']:,}")
print(f"Total columns:    {summary['total_columns']}")
print(f"Missing values:   {summary['missing_values']}")
print(f"Duplicate rows:   {summary['duplicate_rows']}")
print(f"Memory usage:     {summary['memory_usage_mb']:.2f} MB")
print(f"Price range:      ${summary['price_stats']['min']:.0f} — ${summary['price_stats']['max']:.0f}")
print(f"Price median:     ${summary['price_stats']['median']:.0f}")
print(f"Price mean:       ${summary['price_stats']['mean']:.0f}")
print(f"Price P95:        ${summary['price_stats']['p95']:.0f}")

# Persist to CSV
df_clean.to_csv(processor.output_path, index=False)
print(f'\nSuccess: Clean dataset saved to {processor.output_path}')
